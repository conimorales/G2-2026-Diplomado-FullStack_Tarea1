# %% [markdown]
# 1- Repocreado en GitHub con READMEinicial
# Se creo el readme

# %% [markdown]
# .gitignore para web (ver Apéndice A)
# Se agrego Gitignore

# %% [markdown]
# Branch protection en main: requiere PR + Code Review aprobado
# Branch tiene protección, imagen carpeta 3.branch protection.png

# %% [markdown]
# Issues template básico
